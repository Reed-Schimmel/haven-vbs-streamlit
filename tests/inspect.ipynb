# %%
import pandas as pd
import numpy as np

# %%
test_files = ['Simulation_1.csv', 'Simulation_2.csv', 'Simulation_3.csv', 'Specific_Offshores.csv', 'Specific_Onshores.csv']
columns = [pd.read_csv(test_file, sep='\t').columns.to_list() for test_file in test_files]
columns = list(set([col for cols in columns for col in cols]))
columns
# Out:
# ['Total VBS',
#  'Mcap Ratio',
#  'xUSD to onshore',
#  'Max Onshore xUSD',
#  'Error Message',
#  'Max Onshore XHV',
#  'Mcap VBS',
#  'XHV Supply',
#  'XHV Price',
#  'XHV Mcap',
#  'Max Offshore XHV',
#  'Spread Ratio',
#  'xUSD (vault)',
#  'XHV to offshore',
#  'Collateral Needed (XHV)',
#  'xAssets Mcap',
#  'Shore Type',
#  'XHV (vault)',
#  'Slippage VBS',
#  'Spread VBS']

# %%
sim1_df = pd.read_csv('Simulation_1.csv', sep='\t')
sim1_df
# Out:
#   Shore Type  XHV (vault)  xUSD (vault)   XHV Supply  XHV Price     XHV Mcap  \
# 0    Onshore    500000.00   15000000.00  28500000.00       0.42  11970000.00
# 1    Onshore    509908.02   14995838.63  28509908.02       0.56  15965548.49
# 2    Onshore    521429.75   14989386.46  28521429.75       0.48  13690286.28
# 3    Onshore    532419.54   14984111.36  28532419.54       0.61  17404775.92
# 4    Onshore    544588.77   14976688.13  28544588.77       0.52  14843186.16
# 5    Onshore    556500.81   14970493.87  28556500.81       0.50  14278250.41
# 6    Onshore    568462.83   14964512.86  28568462.83       0.42  11998754.39
#
#    xAssets Mcap  Mcap Ratio  Spread Ratio  Mcap VBS  Spread VBS  Slippage VBS  \
# 0   16000000.00      1.3367        0.0000   46.2459     50.4641        0.0000
# 1   15995838.63      1.0019        0.0000   40.0379     44.2562        0.0000
# 2   15989386.46      1.1679        0.0000   43.2284     47.4467        0.0000
# ...

# %%
sim2_df = pd.read_csv('Simulation_2.csv', sep='\t')
sim2_df
# Out:
#   Shore Type  XHV (vault)  xUSD (vault)   XHV Supply  XHV Price      XHV Mcap  \
# 0   Offshore   2014564.00          0.00  26281886.00       7.45  1.958001e+08
# 1   Offshore   1739810.60    2046912.83  26007132.60       3.66  9.518611e+07
# 2   Offshore   1334256.11    3531242.26  25601578.11       1.38  3.533018e+07
# 3    Onshore   1108862.52    3842285.41  25376184.52       0.86  2.182352e+07
# 4    Onshore   1204456.59    3760074.51  25471778.59       0.56  1.426420e+07
# 5    Onshore   1296102.30    3708752.91  25563424.30       0.48  1.227044e+07
# 6    Onshore   1388381.36    3664458.96  25655703.36       0.61  1.564998e+07
# 7    Onshore   1498594.39    3597229.01  25765916.39       0.52  1.339828e+07
# 8    Onshore   1611170.99    3538689.18  25878492.99       0.50  1.293925e+07
# 9    Onshore   1730991.75    3478778.80  25998313.75       0.42  1.091929e+07
#
#    xAssets Mcap  Mcap Ratio  Spread Ratio  Mcap VBS  Spread VBS  Slippage VBS  \
# ...

# %%
sim3_df = pd.read_csv('Simulation_3.csv', sep='\t')
sim3_df
# Out:
#    Shore Type  XHV (vault)  xUSD (vault)   XHV Supply  XHV Price     XHV Mcap  \
# 0     Onshore    500000.00   16000000.00  28500000.00       0.56  15960000.00
# 1     Onshore    510707.14   15994004.00  28510707.14       0.50  14255353.57
# 2     Onshore    521096.14   15988809.50  28521096.14       0.48  13690126.15
# 3     Onshore    531503.45   15983813.99  28531503.45       0.40  11412601.38
# 4     Onshore    541268.28   15979908.06  28541268.28       0.35   9989443.90
# 5     Onshore    550619.48   15976635.14  28550619.48       0.30   8565185.84
# 6     Onshore    559476.55   15973978.02  28559476.55       0.25   7139869.14
# 7     Onshore    567742.59   15971911.51  28567742.59       0.20   5713548.52
# 8     Onshore    575296.34   15970400.76  28575296.34       0.15   4286294.45
# 9     Onshore    581976.47   15969398.74  28581976.47       0.10   2858197.65
# 10    Onshore    587544.87   15968841.90  28587544.87       0.05   1429377.24
# ...

# %% [markdown]
# ---

# %%
offshore_df = pd.read_csv('Specific_Offshores.csv', sep='\t')
print(offshore_df.info())
offshore_df#.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1368 entries, 0 to 1367
# Data columns (total 19 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Shore Type               1368 non-null   object
#  1   XHV (vault)              1368 non-null   float64
#  2   XHV to offshore          1368 non-null   float64
#  3   xUSD (vault)             1368 non-null   float64
#  4   xUSD to onshore          1368 non-null   float64
#  5   XHV Supply               1368 non-null   float64
#  6   XHV Price                1368 non-null   float64
#  7   XHV Mcap                 1368 non-null   float64
#  8   xAssets Mcap             1368 non-null   float64
#  9   Mcap Ratio               1368 non-null   float64
#  10  Spread Ratio             1368 non-null   float64
#  11  Mcap VBS                 1368 non-null   float64
#  12  Spread VBS               1368 non-null   float64
# ...

# %%
offshore_df['Error Message'].unique()
# Out:
# array([nan, 'offshore amount greater than block limit',
#        'incorrect offshore amount', 'not enough collateral available'],
#       dtype=object)

# %%
# import math
# help(math.exp)

# %%
onshore_df = pd.read_csv('Specific_Onshores.csv', sep='\t')
onshore_df.head(13)
# onshore_df.describe()
# Out:
#         XHV (vault)  XHV to offshore  xUSD (vault)  xUSD to onshore  \
# count  1.051000e+03           1051.0  1.051000e+03     1.051000e+03
# mean   7.625491e+05              0.0  5.542360e+04     2.055735e+04
# std    8.397827e+05              0.0  3.089920e+05     8.356590e+04
# min    2.000000e+01              0.0  2.000000e+00     0.000000e+00
# 25%    9.907650e+04              0.0  2.975000e+02     2.000000e+02
# 50%    4.747040e+05              0.0  1.809000e+03     1.129100e+03
# 75%    1.224395e+06              0.0  1.005750e+04     6.924050e+03
# max    4.169034e+06              0.0  4.127272e+06     1.005319e+06
#
#          XHV Supply    XHV Price      XHV Mcap  xAssets Mcap   Mcap Ratio  \
# count  1.051000e+03  1051.000000  1.051000e+03  1.051000e+03  1051.000000
# mean   1.874774e+07     6.711037  1.090191e+08  1.076153e+07     0.148352
# std    5.004538e+06     5.340720  7.121250e+07  8.447781e+06     0.178694
# ...

# %%
help(onshore_df.drop)
# Out:
# Help on method drop in module pandas.core.frame:
#
# drop(labels: 'IndexLabel' = None, axis: 'Axis' = 0, index: 'IndexLabel' = None, columns: 'IndexLabel' = None, level: 'Level' = None, inplace: 'bool' = False, errors: 'IgnoreRaise' = 'raise') -> 'DataFrame | None' method of pandas.core.frame.DataFrame instance
#     Drop specified labels from rows or columns.
#
#     Remove rows or columns by specifying label names and corresponding
#     axis, or by specifying directly index or column names. When using a
#     multi-index, labels on different levels can be removed by specifying
#     the level. See the `user guide <advanced.shown_levels>`
#     for more information about the now unused levels.
#
#     Parameters
#     ----------
#     labels : single label or list-like
#         Index or column labels to drop. A tuple will be used as a single
#         label and not treated as a list-like.
#     axis : {0 or 'index', 1 or 'columns'}, default 0
# ...

# %%
onshore_df[onshore_df['xAssets Mcap'] == 0]
# Out:
# Empty DataFrame
# Columns: [Shore Type, XHV (vault), XHV to offshore, xUSD (vault), xUSD to onshore, XHV Supply, XHV Price, XHV Mcap, xAssets Mcap, Mcap Ratio, Spread Ratio, Mcap VBS, Spread VBS, Slippage VBS, Total VBS, Max Offshore XHV, Max Onshore xUSD, Collateral Needed (XHV), Error Message]
# Index: []

# %%
onshore_df.drop(onshore_df[onshore_df['xAssets Mcap'] == 0].index).reset_index()
# Out:
#       index        Shore Type  XHV (vault)  XHV to offshore  xUSD (vault)  \
# 0         0  Onshore Specific     807581.0              0.0         478.0
# 1         1  Onshore Specific     378549.0              0.0       27333.0
# 2         2  Onshore Specific     147904.0              0.0           3.0
# 3         3  Onshore Specific    2815869.0              0.0       23176.0
# 4         4  Onshore Specific     776499.0              0.0       30454.0
# ...     ...               ...          ...              ...           ...
# 1047   1047  Onshore Specific     282148.0              0.0       14718.0
# 1048   1048  Onshore Specific    1581924.0              0.0        9978.0
# 1049   1049  Onshore Specific    2470802.0              0.0         480.0
# 1050   1050  Onshore Specific      12220.0              0.0        7000.0
# 1051   1051  Onshore Specific     829749.0              0.0        1522.0
#
#       xUSD to onshore  XHV Supply  XHV Price      XHV Mcap  xAssets Mcap  \
# ...

# %%
onshore_df['Error Message'].unique()
# Out:
# array([nan, 'incorrect onshore amount',
#        'not enough xUSD available to onshore',
#        'not enough collateral available'], dtype=object)

# %%
{col: "TODO" for col in onshore_df.columns.to_list()}
# Out:
# {'Shore Type': 'TODO',
#  'XHV (vault)': 'TODO',
#  'XHV to offshore': 'TODO',
#  'xUSD (vault)': 'TODO',
#  'xUSD to onshore': 'TODO',
#  'XHV Supply': 'TODO',
#  'XHV Price': 'TODO',
#  'XHV Mcap': 'TODO',
#  'xAssets Mcap': 'TODO',
#  'Mcap Ratio': 'TODO',
#  'Spread Ratio': 'TODO',
#  'Mcap VBS': 'TODO',
#  'Spread VBS': 'TODO',
#  'Slippage VBS': 'TODO',
#  'Total VBS': 'TODO',
#  'Max Offshore XHV': 'TODO',
#  'Max Onshore xUSD': 'TODO',
#  'Collateral Needed (XHV)': 'TODO',
#  'Error Message': 'TODO'}

# %%
offshore_df = pd.read_csv('Specific_Offshores.csv', sep='\t')
offshore_df
# Out:
#              Shore Type  XHV (vault)  XHV to offshore  xUSD (vault)  \
# 0     Offshore Specific      19057.0           3478.0           0.0
# 1     Offshore Specific        701.0            137.0           0.0
# 2     Offshore Specific        400.0             73.0           0.0
# 3     Offshore Specific    1392548.0         223873.0           0.0
# 4     Offshore Specific       1684.0            715.0           0.0
# ...                 ...          ...              ...           ...
# 1364  Offshore Specific    1508585.0         207984.0           0.0
# 1365  Offshore Specific    1376697.0         155182.3           0.0
# 1366  Offshore Specific      59964.0          19074.0           0.0
# 1367  Offshore Specific     725458.0          84558.6           0.0
# 1368  Offshore Specific        541.0            102.9           0.0
#
#       xUSD to onshore  XHV Supply  XHV Price      XHV Mcap  xAssets Mcap  \
# 0                 0.0  23997040.0       3.09  7.415085e+07    19482217.0
# ...

# %%
offshore_df[offshore_df['xAssets Mcap'] == 0]
# Out:
# Empty DataFrame
# Columns: [Shore Type, XHV (vault), XHV to offshore, xUSD (vault), xUSD to onshore, XHV Supply, XHV Price, XHV Mcap, xAssets Mcap, Mcap Ratio, Spread Ratio, Mcap VBS, Spread VBS, Slippage VBS, Total VBS, Max Offshore XHV, Max Onshore xUSD, Collateral Needed (XHV), Error Message]
# Index: []

# %%
{col: "TODO" for col in offshore_df.columns.to_list()}
# Out:
# {'Shore Type': 'TODO',
#  'XHV (vault)': 'TODO',
#  'XHV to offshore': 'TODO',
#  'xUSD (vault)': 'TODO',
#  'xUSD to onshore': 'TODO',
#  'XHV Supply': 'TODO',
#  'XHV Price': 'TODO',
#  'XHV Mcap': 'TODO',
#  'xAssets Mcap': 'TODO',
#  'Mcap Ratio': 'TODO',
#  'Spread Ratio': 'TODO',
#  'Mcap VBS': 'TODO',
#  'Spread VBS': 'TODO',
#  'Slippage VBS': 'TODO',
#  'Total VBS': 'TODO',
#  'Max Offshore XHV': 'TODO',
#  'Max Onshore xUSD': 'TODO',
#  'Collateral Needed (XHV)': 'TODO',
#  'Error Message': 'TODO'}

# %%
#pd.testing.assert_frame_equal(df1, df2, check_exact=False, check_less_precise=3)
offshore_df.dtypes == float
offshore_df.columns[offshore_df.dtypes == float]
# Out:
# Index(['XHV (vault)', 'XHV to offshore', 'xUSD (vault)', 'xUSD to onshore',
#        'XHV Supply', 'XHV Price', 'XHV Mcap', 'xAssets Mcap', 'Mcap Ratio',
#        'Spread Ratio', 'Mcap VBS', 'Spread VBS', 'Slippage VBS', 'Total VBS',
#        'Max Offshore XHV', 'Max Onshore xUSD', 'Collateral Needed (XHV)'],
#       dtype='object')

# %%
10 ** 3
# Out:
# 1000

# %%
offshore_df.dtypes.to_dict()# == float
# Out:
# {'Shore Type': dtype('O'),
#  'XHV (vault)': dtype('float64'),
#  'XHV to offshore': dtype('float64'),
#  'xUSD (vault)': dtype('float64'),
#  'xUSD to onshore': dtype('float64'),
#  'XHV Supply': dtype('float64'),
#  'XHV Price': dtype('float64'),
#  'XHV Mcap': dtype('float64'),
#  'xAssets Mcap': dtype('float64'),
#  'Mcap Ratio': dtype('float64'),
#  'Spread Ratio': dtype('float64'),
#  'Mcap VBS': dtype('float64'),
#  'Spread VBS': dtype('float64'),
#  'Slippage VBS': dtype('float64'),
#  'Total VBS': dtype('float64'),
#  'Max Offshore XHV': dtype('float64'),
#  'Max Onshore xUSD': dtype('float64'),
#  'Collateral Needed (XHV)': dtype('float64'),
#  'Error Message': dtype('O')}

# %%
help(offshore_df.astype)
# Out:
# Help on method astype in module pandas.core.generic:
#
# astype(dtype, copy: 'bool_t' = True, errors: 'IgnoreRaise' = 'raise') -> 'NDFrameT' method of pandas.core.frame.DataFrame instance
#     Cast a pandas object to a specified dtype ``dtype``.
#
#     Parameters
#     ----------
#     dtype : data type, or dict of column name -> data type
#         Use a numpy.dtype or Python type to cast entire pandas object to
#         the same type. Alternatively, use {col: dtype, ...}, where col is a
#         column label and dtype is a numpy.dtype or Python type to cast one
#         or more of the DataFrame's columns to column-specific types.
#     copy : bool, default True
#         Return a copy when ``copy=True`` (be very careful setting
#         ``copy=False`` as changes to values then may propagate to other
#         pandas objects).
#     errors : {'raise', 'ignore'}, default 'raise'
#         Control raising of exceptions on invalid data for provided dtype.
#
# ...

# %%
(offshore_df['Spread Ratio'] * 10000).astype(int).astype(float) / 10000
# Out:
# 0       0.7373
# 1       0.7460
# 2       0.7274
# 3       0.8968
# 4       0.9994
#          ...
# 1364    0.7400
# 1365    0.8893
# 1366    0.9057
# 1367    0.8826
# 1368    0.7255
# Name: Spread Ratio, Length: 1369, dtype: float64
